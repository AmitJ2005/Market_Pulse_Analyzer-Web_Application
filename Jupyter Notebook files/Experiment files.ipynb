# %%
# !pip install yahooquery

# %%
from yahooquery import search

# Replace 'COMPANY_NAME_TO_CHECK' with the specific company name you want to check
company_name_to_check = ' Tata Power Company'

try:
    # Use Yahoo Finance search to get stock symbols based on the company name
    result = search(company_name_to_check)

    if result['quotes']:
        # Take the first stock symbol from the search results
        stock_symbol = result['quotes'][0]['symbol']
        print(f"Stock symbol for {company_name_to_check}: {stock_symbol}")
    else:
        # Handle the case where no stock symbol is found
        print(f"No stock symbol found for {company_name_to_check}")
except Exception as e:
    print(f"Error fetching stock symbol for {company_name_to_check}: {e}")
# Out:
# Stock symbol for  Tata Power Company: TATAPOWER.NS

# %%
stock_symbol
# Out:
# 'TIMKEN.NS'

# %%
import yfinance as yf

# Specify the stock symbol and date range
stock_symbol = "TATAPOWER.BO"
start_date = "2023-01-01"
end_date = "2023-12-31"

# Fetch stock data with one-day interval
stock_data_daily = yf.download(stock_symbol, start=start_date, end=end_date, interval='1d')

# Print the stock data
stock_data_daily
# Out:
# D:\anaconda\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-02  208.699997  212.199997  208.149994  211.750000  209.795685
# 2023-01-03  212.199997  213.050003  210.000000  211.250000  209.300293
# 2023-01-04  211.000000  211.000000  205.850006  208.100006  206.179382
# 2023-01-05  209.800003  209.800003  205.250000  207.649994  205.733521
# 2023-01-06  207.800003  208.750000  204.100006  205.399994  203.504288
# ...                ...         ...         ...         ...         ...
# 2023-12-22  331.149994  332.000000  323.600006  326.600006  326.600006
# 2023-12-26  328.899994  331.350006  324.799988  325.149994  325.149994
# ...

# %%
import yfinance as yf
import pandas as pd

# Replace 'RELIANCE.BSE' with the symbol you are interested in
symbol = 'RELIANCE.BO'

# Download historical data as a pandas DataFrame
data = yf.download(symbol, period='max')

# Reset the index to have the 'Date' as a column
df = data.reset_index()

# Display the DataFrame
print(df.head())
# Out:
# D:\anaconda\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#
# [*********************100%%**********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close  Volume
# 0 2000-01-04  67.224998  67.224998  67.224998  67.224998  35.767727    6400
# 1 2000-01-05  68.000000  68.000000  68.000000  68.000000  36.180061  418568
# 2 2000-01-12  72.750000  72.750000  72.750000  72.750000  38.707340    4200
# 3 2000-02-07  86.787498  86.787498  86.787498  86.787498  46.176140    8000
# 4 2000-02-14  90.000000  90.000000  90.000000  90.000000  47.885376    2000

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2000-01-04    67.224998    67.224998    67.224998    67.224998
# 1    2000-01-05    68.000000    68.000000    68.000000    68.000000
# 2    2000-01-12    72.750000    72.750000    72.750000    72.750000
# 3    2000-02-07    86.787498    86.787498    86.787498    86.787498
# 4    2000-02-14    90.000000    90.000000    90.000000    90.000000
# ...         ...          ...          ...          ...          ...
# 5784 2024-01-19  2753.000000  2753.000000  2716.850098  2735.050049
# 5785 2024-01-23  2732.149902  2742.750000  2645.000000  2656.000000
# 5786 2024-01-24  2660.000000  2699.000000  2649.000000  2688.699951
# 5787 2024-01-25  2684.500000  2725.000000  2670.050049  2710.350098
# 5788 2024-01-29  2713.199951  2905.000000  2713.199951  2896.149902
#
#         Adj Close   Volume
# 0       35.767727     6400
# 1       36.180061   418568
# 2       38.707340     4200
# 3       46.176140     8000
# ...

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import yfinance as yf
from pprint import pprint

# Define the stock symbol
symbol = "TATAPOWER.NS"

# Create a Ticker object for the stock
stock_ticker = yf.Ticker(symbol)

# Get company information
company_info = stock_ticker.info

# Pretty-print the company information
pprint(company_info)
# Out:
# {'52WeekChange': 0.922871,
#  'SandP52WeekChange': 0.22382951,
#  'address1': 'Corporate Center B',
#  'address2': '34 Sant Tukaram Road Carnac Bunder',
#  'ask': 402.3,
#  'auditRisk': 7,
#  'averageDailyVolume10Day': 20033143,
#  'averageVolume': 21961932,
#  'averageVolume10days': 20033143,
#  'beta': 0.821,
#  'bid': 402.25,
#  'boardRisk': 5,
#  'bookValue': 98.076,
#  'city': 'Mumbai',
#  'companyOfficers': [{'age': 61,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
#                       'name': 'Dr. Praveer  Sinha',
#                       'title': 'CEO, MD & Director',
#                       'totalPay': 92075442,
#                       'unexercisedValue': 0,
#                       'yearBorn': 1962},
#                      {'age': 53,
#                       'exercisedValue': 0,
#                       'fiscalYear': 2023,
#                       'maxAge': 1,
# ...

# %%
for key, value in company_info.items():
    print(f"{key}: {value}")
# Out:
# address1: Corporate Center B
# address2: 34 Sant Tukaram Road Carnac Bunder
# city: Mumbai
# zip: 400 009
# country: India
# phone: 91 22 6665 8282
# website: https://www.tatapower.com
# industry: Utilities - Independent Power Producers
# industryKey: utilities-independent-power-producers
# industryDisp: Utilities - Independent Power Producers
# sector: Utilities
# sectorKey: utilities
# sectorDisp: Utilities
# ...

# %%
import yfinance as yf

# Define the stock symbol
symbol = "TATAPOWER.NS"

# Create a Ticker object for the stock
stock_ticker = yf.Ticker(symbol)

# Get company information
company_info = stock_ticker.info

# Extracting required information
general_info = {
    "Company Name": company_info.get("longName", ""),
    "Industry": company_info.get("industry", ""),
    "Website" : company_info.get("website", ""),
    "Total Employees": company_info.get("fullTimeEmployees"),
    'about' : company_info.get("longBusinessSummary", ""),
    "Close Price": company_info.get("previousClose", ""),
    "Market Capitalization": company_info.get("marketCap", ""),
    "52 Weaks low": company_info.get("fiftyTwoWeekLow",""),
    "52 Weaks high": company_info.get("fiftyTwoWeekHigh",""),
    "share in Market": company_info.get("floatShares",""),
    "Total Share in Company": company_info.get("sharesOutstanding",""),
    "Total Cash": company_info.get("totalCash"),
    "ebitda": company_info.get("ebitda",),
    "totalCashPerShare": company_info.get("totalCashPerShare"),
    "totalDebt": company_info.get("totalDebt",""),
    "totalRevenue": company_info.get("totalRevenue",""),
    "debtToEquity": company_info.get("debtToEquity",""),
    "revenuePerShare": company_info.get("revenuePerShare",""),
    "freeCashflow": company_info.get("freeCashflow",""),
    "grossMargins": company_info.get("grossMargins",""),
#     'about Company' : company_info.get("longBusinessSummary", "")
}

company_officers = []
for officer in company_info.get("companyOfficers", []):
    officer_info = {
        "Name": officer.get("name", ""),
        "Age": officer.get("age", ""),
        "Position": officer.get("title", ""),
        "Salary": officer.get("totalPay", "")
    }
    company_officers.append(officer_info)

# %%
general_info
# Out:
# {'Company Name': 'The Tata Power Company Limited',
#  'Industry': 'Utilities - Independent Power Producers',
#  'Website': 'https://www.tatapower.com',
# ...

# %%
from yfinance import HistoricalPrices
req = HistoricalPrices('AAPL')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from yfinance import HistoricalPrices
#       2 req = HistoricalPrices('AAPL')
#
# ImportError: cannot import name 'HistoricalPrices' from 'yfinance' (D:\anaconda\Lib\site-packages\yfinance\__init__.py)

# %%
import yfinance as yf

msft = yf.Ticker("TATAPOWER.NS")

# get all stock info
msft.info
# Out:
# {'address1': 'Corporate Center B',
#  'address2': '34 Sant Tukaram Road Carnac Bunder',
#  'city': 'Mumbai',
#  'zip': '400 009',
#  'country': 'India',
#  'phone': '91 22 6665 8282',
#  'website': 'https://www.tatapower.com',
#  'industry': 'Utilities - Independent Power Producers',
#  'industryKey': 'utilities-independent-power-producers',
#  'industryDisp': 'Utilities - Independent Power Producers',
#  'sector': 'Utilities',
#  'sectorKey': 'utilities',
#  'sectorDisp': 'Utilities',
# ...

# %%
# get historical market data
msft.history(period="1mo")
# Out:
# D:\anaconda\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close    Volume  Dividends  Stock Splits
# Date
# 2024-02-12 00:00:00+05:30  379.899994  386.149994  359.200012  361.700012  44078652        0.0           0.0
# 2024-02-13 00:00:00+05:30  361.700012  366.500000  354.600006  365.049988  21221871        0.0           0.0
# 2024-02-14 00:00:00+05:30  364.299988  374.600006  358.200012  373.700012  15216135        0.0           0.0
# 2024-02-15 00:00:00+05:30  376.649994  382.350006  374.750000  378.850006  16001298        0.0           0.0
# 2024-02-16 00:00:00+05:30  383.000000  383.000000  375.250000  376.299988   9592754        0.0           0.0
# ...

# %%
# show meta information about the history (requires history() to be called first)
msft.history_metadata
# Out:
# {'currency': 'INR',
#  'symbol': 'TATAPOWER.NS',
#  'exchangeName': 'NSI',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 820467900,
#  'regularMarketTime': 1710151200,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 19800,
#  'timezone': 'IST',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'regularMarketPrice': 413.15,
#  'chartPreviousClose': 392.1,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'IST',
#    'end': 1710128700,
#    'start': 1710128700,
#    'gmtoffset': 19800},
#   'regular': {'timezone': 'IST',
#    'end': 1710151200,
#    'start': 1710128700,
#    'gmtoffset': 19800},
#   'post': {'timezone': 'IST',
#    'end': 1710151200,
#    'start': 1710151200,
#    'gmtoffset': 19800}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
msft.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
msft.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
msft.capital_gains
# Out:
# []

# %%
msft.get_shares_full(start="2024-01-01", end=None)
# Out:
# 2024-01-02 00:00:00+05:30    3195340032
# 2024-01-02 00:00:00+05:30    3212270080
# 2024-01-11 00:00:00+05:30    3195800064
# 2024-01-12 00:00:00+05:30    3195340032
# 2024-01-17 00:00:00+05:30    3196699904
# 2024-01-17 00:00:00+05:30    3233309952
# 2024-01-18 00:00:00+05:30    3195340032
# 2024-01-18 00:00:00+05:30    3239310080
# 2024-01-24 00:00:00+05:30    3217949952
# 2024-01-24 00:00:00+05:30    3196260096
# 2024-01-25 00:00:00+05:30    3195340032
# 2024-02-02 00:00:00+05:30    3195340032
# 2024-02-02 00:00:00+05:30    3201910016
# 2024-02-07 00:00:00+05:30    3195340032
# 2024-02-07 00:00:00+05:30    3203059968
# 2024-02-09 00:00:00+05:30    3196519936
# 2024-02-10 00:00:00+05:30    3195340032
# 2024-02-11 00:00:00+05:30    3195340032
# 2024-02-13 00:00:00+05:30    3463899904
# 2024-02-13 00:00:00+05:30    3195780096
# 2024-02-14 00:00:00+05:30    3195340032
# 2024-02-17 00:00:00+05:30    3195340032
# 2024-02-17 00:00:00+05:30    3216570112
# ...

# %%
msft.income_stmt
# Out:
#                                                             2023-03-31  ...          2020-03-31
# Tax Effect Of Unusual Items                          -549834499.175371  ...    639631755.033444
# Tax Rate For Calcs                                            0.301875  ...            0.270881
# Normalized EBITDA                                       131245200000.0  ...       90865900000.0
# Total Unusual Items                                      -1821400000.0  ...        2361300000.0
# Total Unusual Items Excluding Goodwill                   -1821400000.0  ...        2361300000.0
# Net Income From Continuing Operation Net Minori...       33364400000.0  ...       14276100000.0
# Reconciled Depreciation                                  34412600000.0  ...       26335600000.0
# Reconciled Cost Of Revenue                              410427400000.0  ...      186784800000.0
# EBITDA                                                  129423800000.0  ...       93227200000.0
# ...

# %%
msft.quarterly_income_stmt
# Out:
#                                                         2023-12-31      2023-09-30  ...         2023-03-31      2022-12-31
# Tax Effect Of Unusual Items                                    0.0             0.0  ...  -344849762.104191             0.0
# Tax Rate For Calcs                                         0.27717        0.173294  ...           0.189332             0.3
# Normalized EBITDA                                    35092900000.0   33384000000.0  ...      31345400000.0   38155700000.0
# Total Unusual Items                                            0.0             0.0  ...      -1821400000.0             0.0
# Total Unusual Items Excluding Goodwill                         0.0             0.0  ...      -1821400000.0             0.0
# Net Income From Continuing Operation Net Minori...    9530100000.0    8755300000.0  ...       7777300000.0    9450200000.0
# Reconciled Depreciation                               9262700000.0    9258900000.0  ...       9263000000.0    8532600000.0
# ...

# %%
msft.balance_sheet
# Out:
#                                                       2023-03-31      2022-03-31      2021-03-31      2020-03-31
# Ordinary Shares Number                              3196991847.0    3196991847.0    3195339547.0    2704773510.0
# Share Issued                                        3196991847.0    3196991847.0    3195339547.0    2704773510.0
# Net Debt                                          447847600000.0  445128500000.0  395012900000.0  464942600000.0
# Total Debt                                        529230900000.0  511952100000.0  467082200000.0  519159800000.0
# Tangible Book Value                               255477800000.0  192170700000.0  191818400000.0  165622700000.0
# ...                                                          ...             ...             ...             ...
# Cash Cash Equivalents And Short Term Investments   53393600000.0   34877600000.0   41691600000.0   25610100000.0
# ...

# %%
msft.quarterly_balance_sheet
# Out:
#                                                       2023-09-30      2023-03-31
# Ordinary Shares Number                              3195339547.0    3196991847.0
# Share Issued                                        3195339547.0    3196991847.0
# Net Debt                                          448735300000.0  447847600000.0
# Total Debt                                        525255100000.0  529230900000.0
# Tangible Book Value                               269807800000.0  255477800000.0
# ...                                                          ...             ...
# Cash Cash Equivalents And Short Term Investments  114065300000.0   53393600000.0
# Other Short Term Investments                       79219700000.0   11496000000.0
# Cash And Cash Equivalents                          34845600000.0   41897600000.0
# Cash Equivalents                                             NaN   19861500000.0
# Cash Financial                                               NaN   22036100000.0
#
# ...

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader as pdr

# Load MSFT stock data
msft = pdr.get_data_yahoo('TATAPOWER.NS')

# Check if 'msft' is a DataFrame
print(type(msft))

# If 'msft' is indeed a DataFrame, you can access the 'Total Revenue' column
if isinstance(msft, pd.DataFrame):
    # Assuming 'Total Revenue' is a column in the DataFrame
    total_revenue_column = msft[['Total Revenue']]
    print(total_revenue_column)
else:
    print("msft is not a DataFrame.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas_datareader as pdr
#       3 # Load MSFT stock data
# ----> 4 msft = pdr.get_data_yahoo('TATAPOWER.NS')
#       6 # Check if 'msft' is a DataFrame
#       7 print(type(msft))
#
# File D:\anaconda\Lib\site-packages\pandas_datareader\data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File D:\anaconda\Lib\site-packages\pandas_datareader\base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
# ...
