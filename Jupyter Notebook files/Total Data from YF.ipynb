# %%
import yfinance as yf

# %%
msft = yf.Ticker("MRF.NS")

# %% [markdown]
# ## Get all stock info

# %%
msft.info
# Out:
# {'address1': 'No. 114, Greams Road',
#  'city': 'Chennai',
#  'zip': '600006',
#  'country': 'India',
#  'phone': '91 44 2829 2777',
#  'fax': '91 44 2829 5087',
#  'website': 'https://www.mrftyres.com',
#  'industry': 'Auto Parts',
#  'industryKey': 'auto-parts',
#  'industryDisp': 'Auto Parts',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %% [markdown]
# ## Get historical market data

# %%
msft.history(period="max")
# Out:
# D:\anaconda\Lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
#                                  Open        High         Low       Close  \
# Date
# 1996-01-01 00:00:00+05:30    6.071526    6.114533    6.023460    6.096824
# 1996-01-02 00:00:00+05:30    6.096822    6.155008    5.975392    6.020928
# 1996-01-03 00:00:00+05:30    6.020930    6.081646    5.972864    5.982983
# 1996-01-04 00:00:00+05:30    5.982983    5.970334    5.848903    5.894440
# 1996-01-05 00:00:00+05:30    5.894439    6.020929    5.818545    6.010810
# ...                               ...         ...         ...         ...
# 2024-03-04 00:00:00+05:30  381.049988  394.000000  380.200012  391.750000
# 2024-03-05 00:00:00+05:30  392.000000  399.950012  390.500000  396.149994
# ...

# %% [markdown]
# ## Show meta information about the history (requires history() to be called first

# %%
msft.history_metadata
# Out:
# {'currency': 'INR',
#  'symbol': 'TATAPOWER.NS',
#  'exchangeName': 'NSI',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 820467900,
#  'regularMarketTime': 1710151200,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 19800,
#  'timezone': 'IST',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'regularMarketPrice': 413.15,
#  'chartPreviousClose': 392.1,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'IST',
#    'start': 1710128700,
#    'end': 1710128700,
#    'gmtoffset': 19800},
#   'regular': {'timezone': 'IST',
#    'start': 1710128700,
#    'end': 1710151200,
#    'gmtoffset': 19800},
#   'post': {'timezone': 'IST',
#    'start': 1710151200,
#    'end': 1710151200,
#    'gmtoffset': 19800}},
#  'dataGranularity': '1d',
#  'range': '1mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %% [markdown]
# ## show actions (dividends, splits, capital gains)

# %%
msft.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
msft.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
msft.splits
# Out:
# Series([], Name: Stock Splits, dtype: float64)

# %%
msft.capital_gains  # only for mutual funds & etfs
# Out:
# []

# %% [markdown]
# ## show share count

# %%
msft.get_shares_full(start="2024-01-01", end=None)
# Out:
# 2024-01-02 00:00:00+05:30    3195340032
# 2024-01-02 00:00:00+05:30    3212270080
# 2024-01-11 00:00:00+05:30    3195800064
# 2024-01-12 00:00:00+05:30    3195340032
# 2024-01-17 00:00:00+05:30    3196699904
# 2024-01-17 00:00:00+05:30    3233309952
# 2024-01-18 00:00:00+05:30    3195340032
# 2024-01-18 00:00:00+05:30    3239310080
# 2024-01-24 00:00:00+05:30    3217949952
# 2024-01-24 00:00:00+05:30    3196260096
# 2024-01-25 00:00:00+05:30    3195340032
# 2024-02-02 00:00:00+05:30    3195340032
# 2024-02-02 00:00:00+05:30    3201910016
# 2024-02-07 00:00:00+05:30    3195340032
# 2024-02-07 00:00:00+05:30    3203059968
# 2024-02-09 00:00:00+05:30    3196519936
# 2024-02-10 00:00:00+05:30    3195340032
# 2024-02-11 00:00:00+05:30    3195340032
# 2024-02-13 00:00:00+05:30    3463899904
# 2024-02-13 00:00:00+05:30    3195780096
# 2024-02-14 00:00:00+05:30    3195340032
# 2024-02-17 00:00:00+05:30    3195340032
# 2024-02-17 00:00:00+05:30    3216570112
# ...

# %% [markdown]
# # show financials:

# %% [markdown]
# ## income statement

# %%
msft.income_stmt
# Out:
#                                                            2023-03-31  \
# Tax Effect Of Unusual Items                          277319081.272085
# Tax Rate For Calcs                                           0.281171
# Normalized EBITDA                                       25428400000.0
# Total Unusual Items                                       986300000.0
# Total Unusual Items Excluding Goodwill                    986300000.0
# Net Income From Continuing Operation Net Minori...       7689600000.0
# Reconciled Depreciation                                 12530500000.0
# Reconciled Cost Of Revenue                             158572800000.0
# EBITDA                                                  26414700000.0
# EBIT                                                    13884200000.0
# Net Interest Income                                     -2206100000.0
# Interest Expense                                         3186800000.0
# ...

# %%
income_statement=msft.income_stmt

# %%
income_statement.loc[["Total Revenue", "Operating Revenue", "Gross Profit", "Operating Income", "Net Income", "Diluted EPS", "Basic EPS", "EBITDA", "EBIT", "Interest Expense", "Net Interest Income", "Total Other Finance Cost", "Tax Provision", "Tax Rate For Calcs", "Operating Revenue", "Special Income Charges", "Other Special Charges", "Diluted NI Availto Com Stockholders", "Net Income Common Stockholders", "Basic Average Shares", "Diluted Average Shares"]]
# Out:
#                                          2023-03-31      2022-03-31  \
# Total Revenue                        228505600000.0  190271500000.0
# Operating Revenue                    228505600000.0  190271500000.0
# Gross Profit                          69932800000.0   60587800000.0
# Operating Income                      12029400000.0    9581800000.0
# Net Income                             7689600000.0    6692400000.0
# Diluted EPS                                  1813.1         1577.97
# Basic EPS                                    1813.1         1577.97
# EBITDA                                26414700000.0   23663200000.0
# EBIT                                  13884200000.0   11612700000.0
# Interest Expense                       3186800000.0    2533400000.0
# Net Interest Income                   -2206100000.0   -1623100000.0
# Total Other Finance Cost                 77600000.0      94600000.0
# Tax Provision                          3007800000.0    2386900000.0
# ...

# %%
msft.quarterly_income_stmt
# Out:
#                                                         2023-12-31  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                         0.27717
# Normalized EBITDA                                    35092900000.0
# Total Unusual Items                                            0.0
# Total Unusual Items Excluding Goodwill                         0.0
# Net Income From Continuing Operation Net Minori...    9530100000.0
# Reconciled Depreciation                               9262700000.0
# Reconciled Cost Of Revenue                           97769500000.0
# EBITDA                                               35092900000.0
# EBIT                                                 25830200000.0
# Net Interest Income                                 -10942600000.0
# Interest Expense                                     10942600000.0
# Normalized Income                                     9530100000.0
# ...

# %% [markdown]
# ##  balance sheet

# %%
msft.balance_sheet
# Out:
#                                                       2023-03-31  \
# Ordinary Shares Number                              3196991847.0
# Share Issued                                        3196991847.0
# Net Debt                                          447847600000.0
# Total Debt                                        529230900000.0
# Tangible Book Value                               255477800000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   53393600000.0
# Other Short Term Investments                       11496000000.0
# Cash And Cash Equivalents                          41897600000.0
# Cash Equivalents                                   19861500000.0
# Cash Financial                                     22036100000.0
#
#                                                       2022-03-31  \
# Ordinary Shares Number                              3196991847.0
# ...

# %%
msft.quarterly_balance_sheet
# Out:
#                                                       2023-09-30  \
# Ordinary Shares Number                              3195339547.0
# Share Issued                                        3195339547.0
# Net Debt                                          448735300000.0
# Total Debt                                        525255100000.0
# Tangible Book Value                               269807800000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments  114065300000.0
# Other Short Term Investments                       79219700000.0
# Cash And Cash Equivalents                          34845600000.0
# Cash Equivalents                                             NaN
# Cash Financial                                               NaN
#
#                                                       2023-03-31
# Ordinary Shares Number                              3196991847.0
# ...

# %% [markdown]
# ## cash flow statement

# %%
msft.cashflow
# Out:
#                                                  2023-03-31      2022-03-31  \
# Free Cash Flow                                -4968800000.0   -5751300000.0
# Repayment Of Debt                           -118389900000.0  -56842800000.0
# Issuance Of Debt                             107304100000.0  114738800000.0
# Issuance Of Capital Stock                     54607100000.0    7575900000.0
# Capital Expenditure                          -76560100000.0  -72678600000.0
# End Cash Position                             40722800000.0   28290200000.0
# Other Cash Adjustment Outside Changein Cash             NaN    -634300000.0
# Beginning Cash Position                       28290200000.0   35699600000.0
# Effect Of Exchange Rate Changes                1186100000.0     895300000.0
# Changes In Cash                               11246500000.0   -7670400000.0
# Financing Cash Flow                           13407700000.0  -11832000000.0
# ...

# %%
msft.quarterly_cashflow
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.get_income_stmt()  #for more options
# Out:
#                                                             2023-03-31  \
# TaxEffectOfUnusualItems                              -549834499.175371
# TaxRateForCalcs                                               0.301875
# NormalizedEBITDA                                        131245200000.0
# TotalUnusualItems                                        -1821400000.0
# TotalUnusualItemsExcludingGoodwill                       -1821400000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       33364400000.0
# ReconciledDepreciation                                   34412600000.0
# ReconciledCostOfRevenue                                 410427400000.0
# EBITDA                                                  129423800000.0
# EBIT                                                     95011200000.0
# NetInterestIncome                                       -38582500000.0
# InterestExpense                                          40441200000.0
# ...

# %% [markdown]
# ## show holders

# %%
msft.major_holders
# Out:
# Breakdown                         Value
# insidersPercentHeld             0.47221
# institutionsPercentHeld         0.20277
# institutionsFloatPercentHeld    0.38418
# institutionsCount             125.00000

# %%
msft.institutional_holders
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2023-07-31  Vanguard International Stock Index-Emerging Ma...   0.0073
# 1    2023-07-31  Vanguard International Stock Index-Total Intl ...   0.0069
# 2    2023-08-31             iShares Core MSCI Emerging Markets ETF   0.0044
# 3    2023-06-30  Matthews International Fds-Matthews Pacific Ti...   0.0037
# 4    2023-08-31                             iShares MSCI India ETF   0.0026
# 5    2023-08-31                  iShares MSCI Emerging Markets ETF   0.0014
# 6    2023-07-31         DFA Emerging Markets Core Equity Portfolio   0.0012
# 7    2023-07-31  Vanguard Intl Equity Index Fds-FTSE All World ...   0.0011
# 8    2023-08-31                SPDR Portfolio Emerging Markets ETF   0.0010
# 9    2023-05-31  Schwab Strategic Tr-Schwab Emerging Markets Eq...   0.0007
#
#      Shares       Value
# 0  23304200  5468330530
# 1  22194978  5208051587
# 2  13947686  3418577838
# 3  11795802  2616898673
# ...

# %%
msft.insider_transactions
# Out:
#       Shares URL                                  Text  \
# 0   29203689
# 1     250000      Acquisition at price 0.93 per share.
# 2     250000      Acquisition at price 0.85 per share.
# 3     200000
# 4     800000
# 5      13150
# 6      17450
# 7       7000
# 8       9200
# 9   55420707
# 10     64000
# 11   1358608
# 12       125
# 13     25000
# 14       300
# 15     74375
# 16       400
# 17   1085400
#
#                                 Insider                  Position Transaction  \
# 0        ICICI Prudential Balanced Fund  Institution- Corporation
# 1            Chandrasekaran (Natarajan)                UNREPORTED
# 2            Chandrasekaran (Natarajan)                UNREPORTED
# 3            Chandrasekaran (Natarajan)                UNREPORTED
# 4        ICICI Prudential Balanced Fund                  Promoter
# 5                       Jain (Pratibha)                UNREPORTED
# 6                       Jain (Pratibha)                UNREPORTED
# ...

# %%
msft.insider_purchases
# Out:
#        Insider Purchases Last 6m      Shares  Trans
# 0                      Purchases           0      0
# 1                          Sales        <NA>      0
# 2    Net Shares Purchased (Sold)           0      0
# 3      Total Insider Shares Held  1510137088   <NA>
# 4  % Net Shares Purchased (Sold)        <NA>   <NA>
# 5                   % Buy Shares        <NA>   <NA>
# 6                  % Sell Shares        <NA>   <NA>

# %%
msft.insider_roster_holders
# Out:
#                                   Name                  Position URL  \
# 0           Chandrasekaran (Natarajan)                UNREPORTED
# 1       ICICI Prudential Balanced Fund  Institution- Corporation
# 2                       Jain (Abhinav)                UNREPORTED
# 3                      Jain (Pratibha)                UNREPORTED
# 4  Life Insurance Corporation of India  Institution- Corporation
# 5          Matthews Pacific Tiger Fund        Investment Advisor
# 6                     Mistry (Cyrus P)    Non Executive Chairman
# 7  Tata AIA Life Insurance Company Ltd  Institution- Corporation
#
#   Most Recent Transaction Latest Transaction Date  Shares Owned Directly  \
# 0             Acquisition              2020-12-01                 700000
# 1                    Sale              2021-01-11              161631777
# 2             Acquisition              2019-06-28                  24552
# 3             Acquisition              2019-06-28                  37097
# ...

# %% [markdown]
# ## show recommendations

# %%
msft.recommendations
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.recommendations_summary
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
msft.upgrades_downgrades
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default.

# %%
msft.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-02-07 16:00:00+05:30           NaN           NaN          NaN
# 2024-11-06 16:00:00+05:30           NaN           NaN          NaN
# 2024-08-07 16:00:00+05:30           NaN           NaN          NaN
# 2024-05-02 16:00:00+05:30           NaN           NaN          NaN
# 2024-02-09 17:00:00+05:30          2.39          2.96       0.2401
# 2023-11-08 15:00:00+05:30          2.50          2.74       0.0960
# 2023-08-09 17:00:00+05:30          2.20          2.31       0.0500
# 2023-05-04 17:00:00+05:30          3.98          2.43      -0.3894

# %% [markdown]
# ## news

# %%
msft.news
# Out:
# [{'uuid': '43bd3fce-c7a6-3871-9b4f-dfe966ea8511',
#   'title': 'Fortrea Holdings Inc (FTRE) Reports Mixed 2023 Results and Sets 2024 Guidance',
#   'publisher': 'GuruFocus.com',
#   'link': 'https://finance.yahoo.com/news/fortrea-holdings-inc-ftre-reports-115120840.html',
#   'providerPublishTime': 1710157880,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/E.86uyeM1VEYLHIiI6IGDQ--~B/aD01NTc7dz0xMjQyO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/us.finance.gurufocus/7b7c9187b1eb7368d44f836cc7775c73',
#      'width': 1242,
#      'height': 557,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/e_NA65IZaxLKE8Iy2vMJpw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/us.finance.gurufocus/7b7c9187b1eb7368d44f836cc7775c73',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]}},
#  {'uuid': 'ad8ea777-559e-3bf8-b893-df79c6748d76',
# ...
