# %%
import requests
from bs4 import BeautifulSoup
import json

url = "https://www.5paisa.com/stocks/all"

# Define headers to simulate a legitimate browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Make a GET request to the website with headers
response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the div with class 'stock-directory__listname'
    stock_list_div = soup.find('div', class_='stock-directory__listname')

    # Find all ul tags within the div
    ul_tags = stock_list_div.find_all('ul')

    # Initialize a set to store unique stock names
    stock_names_set = set()

    # Iterate through ul tags and extract data from li tags
    for ul_tag in ul_tags:
        li_tags = ul_tag.find_all('li')
        for li_tag in li_tags:
            # Extract the text content from the <a> tag inside <li>
            stock_name = li_tag.find('a').text
            stock_names_set.add(stock_name)
            stock_names_set = {name.replace(" Ltd", "") if " Ltd" in name else name for name in stock_names_set}

    # Convert the set back to a list
    stock_names = list(stock_names_set)

    # Save the data in JSON format
#     with open('stock_names.json', 'w') as json_file:
#         json.dump(stock_names, json_file, indent=2)

    print("Unique stock names")

else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Unique stock names

# %%
stock_names
# Out:
# ['SecUR Credentials',
#  'United Polyfab Gujarat',
#  'Ram Ratna Wires',
#  'Jindal Capital',
#  'Page Industries',
#  'Family Care Hospitals',
#  'Rathi Bars',
#  'Bella Casa Fashion & Retail',
#  'Nalin Lease Finance',
#  'Retina Paints',
#  'Sayaji Hotels (Pune)',
#  'AIA Engineering',
#  'Haldyn Glass',
#  'Jaiprakash Power Ventures',
#  'Laffans Petrochemicals',
#  'P B A Infrastructure',
#  'Shivalik Rasayan',
#  'Career Point',
#  'Gem Spinners India',
#  'Mangalore Refinery And Petrochemicals',
#  'Tourism Finance Corporation of India',
#  'Shiva Mills',
#  'Informed Technologies India',
#  'Balaxi Pharmaceuticals',
#  'Kapil Raj Finance',
#  'Welspun Living',
#  'IDBI Bank',
#  'Gayatri Highways',
#  'Pidilite Industries',
#  'Bharat Immunological & Biological Corporation',
#  'Indo Count Industries',
#  'Ace Integrated Solutions',
#  'Barak Valley Cements',
#  'Ishan International',
#  'Bharti Airtel',
#  'Landmark Property Development Company',
#  'Restile Ceramics',
#  'Arrowhead Seperation Engineering',
#  'Megasoft',
#  'Agio Paper & Industries',
#  'Prakash Woollen & Synthetic Mills',
#  'Polyplex Corporation',
#  'Mawana Sugars',
#  'Modern Insulators',
#  'Magnum Ventures',
#  'Inspire Films',
#  'National Fertilizer',
#  'K K Fincorp',
#  'RBM Infracon',
#  'Sandhar Technologies Limited',
#  'Starteck Finance',
#  'Dolfin Rubbers',
#  'Krishna Institute of Medical Sciences',
#  'Elecon Engineering Company',
#  'Natco Pharma',
#  'Scooters India',
#  'MRF',
#  'Mayur Floorings',
#  'Ashika Credit Capital',
#  'Munoth Communication',
#  'Nifty 4-8 Yr G-Sec',
#  'Cubex Tubings',
#  'Apollo Tyres',
#  'Mallcom (India)',
#  'Silgo Retail',
#  'Ind Bank Housing',
#  'Deepak Chemtex',
#  'CSB Bank',
#  'RTS Power Corporation',
#  'Total Transport Systems',
#  'GCM Securities',
#  'IRM Energy',
#  'Onward Technologies',
#  'Sungold Capital',
#  'Minal Industries',
#  'SRF',
#  'Ador Multi Products',
#  'City Online Services',
#  'GPT Infraprojects',
#  'Biocon',
#  'Tantia Constructions',
#  'Prime Focus',
#  'BSL',
#  'Tuticorin Alkali Chemicals & Fertilizers',
#  'Mitshi India',
#  'ECS Biztech',
#  'Motisons Jewellers',
#  'Gratex Industries',
#  'Almondz Global Securities',
#  'TBO Tek',
#  'Dynamic Portfolio Management & Services',
#  'Solex Energy',
#  'Cubical Financial Services',
#  'Kuber Udyog',
#  'Ambar Protein Industries',
#  'Deccan Health Care',
#  'Priti International',
#  'Mafatlal Industries',
#  'Softsol India',
#  'S V Global Mill',
#  'Aditya Ispat',
#  'Kallam Textiles',
#  'Kakatiya Textiles',
#  'Aarvi Encon',
#  'Macpower CNC Machines',
#  'John Cockerill India',
#  'Whirlpool of India',
#  'AVP Infracon',
#  'Mega Corporation',
#  'Premier Polyfilm',
#  'Intense Technologies',
#  'Bannari Amman Sugars',
#  'HB Portfolio',
#  'Rishi Laser',
#  'Globalspace Technologies',
#  'IOL Chemicals & Pharmaceuticals',
#  'Smiths & Founders (India)',
#  'Delhivery',
#  'Vijay Solvex',
#  'Archit Organosys',
#  'Nettlinx',
#  'Kakatiya Cement Sugar & Industries',
#  'Orissa Minerals Development Company',
#  'Som Datt Finance Corporation',
#  'Waaree Renewables Technologies',
#  'Jay Kailash Namkeen',
#  'GVK Power & Infrastructure',
#  'Deem Roll-Tech',
#  'Suncare Traders',
#  'PG Foils',
#  'Ecoplast',
#  'Cochin Minerals & Rutile',
#  'Ace Software Exports',
#  'Kovai Medical Center & Hospital',
#  'Lincoln Pharmaceuticals',
#  'Inox India',
#  'Venus Remedies',
#  'Antarctica',
#  'Vardhman Textiles',
#  'Panchsheel Organics',
#  'Epuja Spiritech',
#  'Ipca Laboratories',
#  'Colorchips New Media',
#  'Octavius Plantations',
#  'AGS Transact Technologies',
#  'MOIL',
#  'Shalimar Paints',
#  'Nureca',
#  'Rajnish Retail',
#  'Master Trust',
#  'Vadilal Enterprises',
#  'Suratwwala Business Group',
#  'Go Digit General Insurance',
#  'Vishwas Agri Seeds',
#  'Vivo Bio Tech',
#  'Fortune International',
#  'Control Print',
#  'Tata Motors-DVR',
#  'Banswara Syntex',
#  'Infosys',
#  'Superior Industrial Enterprises',
#  'NOCIL',
#  'Saffron Industries',
#  'Deep Diamond India',
#  'Pudumjee Paper Products',
#  'Bajaj Finserv',
#  'Mac Hotels',
#  'LTIMindtree',
#  'Hindustan Zinc',
#  'SRM Energy',
#  'Coral India Finance & Housing',
#  'Glenmark Pharmaceuticals',
#  'Kranti Industries',
#  'Poddar Pigments',
#  'Sun TV Network',
#  'Valiant Communications',
#  'Remedium Lifecare',
#  'Meghmani Organics',
#  'Tamil Nadu Petro Products',
#  'Share India Securities',
#  'Oil & Natural Gas Corpn',
#  'Alkali Metals',
#  'Mercantile Ventures',
#  'TPL Plastech',
#  'HOV Services',
#  'Digidrive Distributors',
#  'Tide Water Oil Co (I)',
#  'Davangere Sugar Company',
#  'Doms Industries',
#  'AA Plus Tradelink',
#  'Eastern Treads',
#  'Sharda Ispat',
#  'Gujarat Intrux',
#  'Agarwal Industrial Corporation',
#  'Balrampur Chini Mills',
#  'GE T&D India',
#  'Rander Corporation',
#  'Ahmedabad Steelcraft',
#  'United Spirits',
#  'Sinnar Bidi Udyog',
#  'Bosch',
#  'Max Healthcare Institute',
#  'WEP Solutions',
#  'ERIS Lifesciences',
#  'HB Leasing & Finance Co',
#  'W H Brady & Co',
#  'IL&FS Engineering & Construction Co',
#  'Auro Impex & Chemicals',
#  'Gujarat Credit Corporation',
#  'KFin Technologies',
#  'Associated Ceramics',
#  'Ashoka Buildcon',
#  'Rainbow Foundations',
#  'Lux Industries',
#  'Signet Industries',
#  'Asian Hotels (East)',
#  'Purv Flexipack',
#  'Jyothy Labs',
#  'Dynamatic Technologies',
#  'Monarch Networth Capital',
#  'Dhanlaxmi Fabrics',
#  'Archies',
#  'AD Manum Finance',
#  'Sofcom Systems',
#  'Allsec Technologies',
#  'RACL Geartech',
#  'Welspun Specialty Solutions',
#  'IP Rings',
#  'Alpine Housing Development Corporation',
#  'Shreevatsaa Finance & Leasing',
#  'Gulf Oil Lubricants India',
#  'Bharat Dynamics',
#  'BKV Industries',
#  'Indian Sucrose',
#  'Emkay Global Financial Services',
#  'Soni Medicare',
#  'Atharv Enterprises',
#  'S Chand & Company',
#  'Soma Textiles & Industries',
#  'KNR Constructions',
#  'Shree Cement',
#  'Shriram Properties',
#  'Nuvoco Vistas Corporation',
#  'ISF',
#  'Priya',
#  'Pradhin',
#  'Godavari Drugs',
#  'Narendra Properties',
#  'ITD Cementation India',
#  'Websol Energy System',
#  'Bank of India',
#  'BCL Industries',
#  'Sundaram Clayton',
#  'Kisan Mouldings',
#  'Rico Auto Industries',
#  'Dhanuka Agritech',
#  'Hindustan Organic Chemicals',
#  'Sakuma Exports',
#  'Clean Science & Technology',
#  'Kody Technolab',
#  'Suumaya Industries',
#  'Grasim Industries- Partly Paidup',
#  'Jainex Aamcol',
#  'F Mec International Financial Services',
#  'Satchmo Holdings',
#  'Yatharth Hospital & Trauma Care Services',
#  'XT Global Infotech',
#  'Cropster Agro',
#  'Jyoti',
#  'Jasch Gauging Technologies',
#  'Beardsell',
#  'West Leisure Resorts',
#  'Martin Burn',
#  'SJVN',
#  'Beryl Securities',
#  'Sadhana Nitro Chem',
#  'Future Consumer',
#  'Empower India',
#  'Black Box',
#  'Prudential Sugar Corporation',
#  'Rollatainers',
#  'Sical Logistics',
#  'Thakkers Developers',
#  'Gala Global Products',
#  'Somany Ceramics',
#  'KBC Global',
#  'Raj Oil Mills',
#  'Spencers Retail',
#  'Max Financial Services',
#  'Salasar Techno Engineering',
#  'Chalet Hotels',
#  'Jayant Infratech',
#  'Pro CLB Global',
#  'Kesar Terminals & Infrastructure',
#  'Biofil Chemicals & Pharmaceuticals',
#  'G G Automotive Gears',
#  'Conart Engineers',
#  'Sangam (India)',
#  'Divyashakti',
#  'VLS Finance',
#  'ICICI Lombard General Insurance Company',
#  'Pramara Promotions',
#  'Vintron Informatics',
#  'Shakti Press',
#  'Mukesh Babu Financial Services',
#  'Shree Hanuman Sugar & Industries',
#  'Salasar Exteriors & Contour',
#  'Sumitomo Chemical India',
#  'Taneja Aerospace & Aviation',
#  'Maha Rashtra Apex Corporation',
#  'Wardwizard Innovations & Mobility',
#  'Capital Trade Links',
#  'J J Finance Corporation',
#  'SPML Infra',
#  '7NR Retail',
#  'Vinayak Polycon International',
#  'Uni Abex Alloy Products',
#  'Seven Hill Industries',
#  'Expo Gas Containers',
#  'Suvidhaa Infoserve',
#  'Oil India',
#  'Precision Electronics',
#  'Le Merite Exports',
#  'TVS Electronics',
#  'Baweja Studios',
#  'Vapi Enterprise',
#  'TPI India',
#  'Vamshi Rubber',
#  'Bank of Maharashtra',
#  'Vivanta Industries',
#  'Goodyear India',
#  'Genesys International Corporation',
#  'Parker Agrochem Exports',
#  'Shyam Metalics & Energy',
#  'RBL Bank',
#  'Rajkamal Synthetics',
#  'Tiaan Consumer',
#  'Tata Power Company',
#  'Valson Industries',
#  'Kavveri Telecom Products',
#  'Rajshree Sugars & Chemicals',
#  'Maruti Infrastructure',
#  'MKP Mobility',
#  'eClerx Services',
#  'Prevest Denpro',
#  'Autoline Industries',
#  'Zenotech Laboratories',
#  'Powergrid Infrastructure Investment Trust',
#  'Alacrity Securities',
#  'Pecos Hotels & Pubs',
#  'Dish TV India',
#  'Rushil Decor',
#  'Candour Techtex',
#  '20 Microns',
#  'Equitas Small Finance Bank',
#  'Abhinav Leasing & Finance',
#  'Lotus Chocolate Company',
#  'Johnson Pharmacare',
#  'Vision Corporation',
#  'Shree Rama Multi-Tech',
#  'Manaksia Coated Metals & Industries',
#  'Flexituff Ventures International',
#  'BASF India',
#  'MSP Steel & Power',
#  'Bandhan Bank',
#  'Lead Reclaim and Rubber Products',
#  'Singer India',
#  'Dhanalaxmi Roto Spinners',
#  'Super Crop Safe',
#  'S P Capital Financing',
#  'CHD Chemicals',
#  'Electrotherm (India)',
#  'Nifty Financial Services 25/50',
#  'Texmo Pipes & Products',
#  'Steelcast',
#  'Saregama India',
#  'BEML Land Assets',
#  'Daikaffil Chemicals India',
#  'Ramco Industries',
#  'Quasar India',
#  'Creative Graphics Solutions India',
#  'Shukra Jewellery',
#  'Gujarat Fluorochemicals',
#  'Waterbase',
#  'Waa Solar',
#  'HB Stockholdings',
#  'K P R Mill',
#  'Stratmont Industries',
#  'Drone Destination',
#  'BF Investment',
#  'Ducon Infratechnologies',
#  'Wockhardt',
#  'Oswal Green Tech',
#  'KMF Builders & Developers',
#  'Dynamic Cables',
#  'Ester Industries',
#  'RHI Magnesita India',
#  'JK Paper',
#  'Mangalam Global Enterprise',
#  'Syschem (India)',
#  'Dhabriya Polywood',
#  'Atul',
#  'Kokuyo Camlin',
#  'Sheetal Cool Products',
#  'Healthy Life Agritec',
#  'Shangar Decor',
#  'Mahindra Holidays & Resorts India',
#  'BLS International Services',
#  'K&R Rail Engineering',
#  'Vistar Amar',
#  'Franklin Industries',
#  'Intec Capital',
#  'Symphony',
#  'Emmbi Industries',
#  'Brigade Enterprises',
#  'GAIL (India)',
#  'Saboo Sodium Chloro',
#  'National Plastic Technologies',
#  'Jullundur Motor Agency (Delhi)',
#  'Riba Textiles',
#  'Sri Ramakrishna Mills (Coimbatore)',
#  'P. H. Capital',
#  'Zenith Fibres',
#  'Symbiox Investment & Trading Co',
#  'Modipon',
#  'Mayank Cattle Food',
#  'Zydus Wellness',
#  'RKEC Projects',
#  'Karnataka Bank',
#  'Goodluck India',
#  'Classic Filaments',
#  'Jhaveri Credits & Capital',
#  'Tatia Global Venture',
#  'East West Holdings',
#  'Central Bank of India',
#  'Asian Hotels (North)',
#  'Kothari Sugars & Chemicals',
#  'SSPDL',
#  'B2B Software Technologies',
#  'Five-Star Business Finance',
#  '5Paisa Capital',
#  'Aspire & Innovative Advertising',
#  'Transpek Industry',
#  'Lancor Holdings',
#  'Accent Microcell',
#  'Jenburkt Pharmaceuticals',
#  'Sintercom India',
#  'Capri Global Capital',
#  'West Coast Paper Mills',
#  'Khandwala Securities',
#  'Utkarsh Small Finance Bank',
#  'Lorenzini Apparels',
#  'Brandbucket Media & Technology',
#  'JK Tyre & Industries',
#  'Lactose (India)',
#  'Aptus Value Housing Finance India',
#  'Centum Electronics',
#  'Esha Media Research',
#  'Hitachi Energy India',
#  'Geecee Ventures',
#  'Infinium Pharmachem',
#  'Precision Camshafts',
#  'Kaushalya Infrastructure Development Corpn',
#  'Bajaj Auto',
#  'Ambuja Cements',
#  'Suven Pharmaceuticals',
#  'Kundan Edifice',
#  'Happiest Minds Technologies',
#  'Colinz Laboratories',
#  'Fino Payments Bank',
#  'Hardwyn India',
#  'Continental Petroleums',
#  'Inditrade Capital',
#  'Birla Corporation',
#  'CIAN Agro Industries & Infrastructure',
#  'Shree Digvijay Cement Co.',
#  'Ruby Mills',
#  'S.M. Gold',
#  'Vidhi Specialty Food Ingredients',
#  'Vimta Labs',
#  'NTPC',
#  'Shah Metacorp',
#  'Integra Engineering India',
#  'Bluechip Tex Industries',
#  'GTN Industries',
#  'Ambo Agritec',
#  'BLS E-Services',
#  'Haria Apparels',
#  'Ausom Enterprise',
#  'K.P. Energy',
#  'Padmanabh Industries',
#  'International Data Management',
#  'Krishna Ventures',
#  'Asia Pack',
#  'Goenka Diamond & Jewels',
#  'Balkrishna Industries',
#  'Shetron',
#  'Zuari Agro Chemicals',
#  'Comfort Intech',
#  'Poddar Housing & Development',
#  'Sunflag Iron & Steel Company',
#  'Heritage Foods',
#  'JK Agri Genetics',
#  'Nirlon',
#  'Modis Navnirman',
#  'Universal Starch Chem Allied',
#  'Purohit Construction',
#  'REC',
#  'Sarla Performance Fibers',
#  'Sayaji Industries',
#  'Dynacons Systems & Solutions',
#  'IDFC',
#  'Andrew Yule & Company',
#  'Roopa Industries',
#  'Bharat Electronics',
#  'ESAF Small Finance Bank',
#  'Bhagiradha Chemicals & Industries',
#  'Prakash Industries',
#  'Dabur India',
#  'Ramasigns Industries',
#  'Adani Energy Solutions',
#  'Spenta International',
#  'KPI Green Energy',
#  'Khaitan Chemicals & Fertilizers',
#  'Swasti Vinayaka Synthetics',
#  'Gujarat Apollo Industries',
#  'Inter Globe Finance',
#  'Dhatre Udyog',
#  'Shivam Autotech',
#  'Platinum Industries',
#  'Dynamic Industries',
#  'Multibase India',
#  'Tata Teleservices (Maharashtra)',
#  'Surana Solar',
#  'Amber Enterprises India',
#  'Chandni Machines',
#  'Clara Industries',
#  'Rama Paper Mills',
#  'Motilal Oswal Financial Services',
#  'PC Jeweller',
#  'Dhampur Bio Organics',
#  'AB Cotspin India',
#  'Ajanta Pharma',
#  'Nifty 15 yr and above G-Sec',
#  'Pasupati Acrylon',
#  'India Steel Works',
#  'Cindrella Financial Services',
#  'ANG Lifesciences India',
#  'Nifty Services Sector',
#  'Stanrose Mafatlal Investment & Finance',
#  'Pratiksha Chemicals',
#  'Rossari Biotech',
#  'Ekam Leasing And Finance Co',
#  'MMTC',
#  'Kamdhenu Ventures',
#  'MRC Agrotech',
#  'Punjab & Sind Bank',
#  'Rajapalayam Mills',
#  'Nandan Denim',
#  'KSB',
#  'Asian Granito India',
#  'Madhusudan Securities',
#  'Patanjali Foods',
#  'Adani Ports & Special Economic Zone',
#  'Andhra Petrochemicals',
#  'Shri Krishna Devcon',
#  'Bright Outdoor Media',
#  'Aurobindo Pharma',
#  'Crop Life Science',
#  'Hisar Metal Industries',
#  'Lee & Nee Software (Exports)',
#  'Saianand Commercial',
#  'Premier Synthetics',
#  'Flomic Global Logistics',
#  'Siyaram Recycling Industries',
#  'Varyaa Creations',
#  'Bheema Cements',
#  'DCG Cables & Wires',
#  'Winpro Industries',
#  'Saptarishi Agro Industries',
#  'Jai Mata Glass',
#  'Ganesh Holdings',
#  'Joindre Capital Services',
#  'ISMT',
#  'VST Tillers Tractors',
#  'Madhucon Projects',
#  'Aadi Industries',
#  'Inox Wind Energy',
#  'Sunrest Lifescience',
#  'Spandana Sphoorty Financial',
#  'Sabrimala Industries India',
#  'Janus Corporation',
#  'Inox Green Energy Services',
#  'Tata Gold Exchange Traded Fund',
#  'Harrisons Malayalam',
#  'Genus Power Infrastructures',
#  'GOCL Corporation',
#  'Emami',
#  'Binani Industries',
#  'Eureka Forbes',
#  'Excel Industries',
#  'Shriram Pistons & Rings',
#  'Menon Pistons',
#  'Shree Rama Newsprint',
#  'Shish Industries',
#  'Ishan Dyes & chemicals',
#  'Vinsys IT Services India',
#  'Tanla Platforms',
#  'Orient Press',
#  'GSS Infotech',
#  'Subex',
#  'Manaksia Aluminium Company',
#  'Gujarat Themis Biosyn',
#  'Kriti Industries (India)',
#  'Suraj Estate Developers',
#  'Allied Digital Services',
#  'Nath Bio-Genes (India)',
#  'Auro Laboratories',
#  'Dhruv Consultancy Services',
#  'Southern Infosys',
#  'Themis Medicare',
#  'Southern Magnesium & Chemicals',
#  'Indus Towers',
#  'Saksoft',
#  'Oswal Yarns',
#  'Elnet Technologies',
#  'Suprajit Engineering',
#  'Mohite Industries',
#  'Vishal Fabrics',
#  'Triveni Enterprises',
#  'Veefin Solutions',
#  'Greenchef Appliances',
#  'Grasim Industries',
#  'Valor Estate',
#  'Pulsar International',
#  'Kaushalya Logistics',
#  'Medico Intercontinental',
#  'Ultracab (India)',
#  'ICICI Bank',
#  'Indiabulls Real Estate',
#  'Sayaji Hotels',
#  'Pasupati Spinning & Weaving Mills',
#  'SpiceJet',
#  'Hercules Hoists',
#  'SBFC Finance',
#  'Viji Finance',
#  'Dhruva Capital Services',
#  'Bajaj Healthcare',
#  'Softtech Engineers',
#  'Pan India Corporation',
#  'Ashirwad Steels & Industries',
#  'Sonal Mercantile',
#  'Betex India',
#  'Modella Woollens',
#  'Innovatus Entertainment Networks',
#  'Global Longlife Hospital and Research',
#  'First Custodian Fund(I)',
#  'Inventure Growth & Securities',
#  'Integrated Hitech',
#  'La Tim Metal & Industries',
#  'Nifty50 Dividend Points',
#  'CFF Fluid Control',
#  'Nifty50 Value 20',
#  'Golkonda Aluminium Extrusions',
#  'RPP Infra Projects',
#  'DigiSpice Technologies',
#  'Kiran Print Pack',
#  'Minda Corporation',
#  'Semac Consultants',
#  'CIL Nova Petrochemicals',
#  'Naperol Investments',
#  'UFO Moviez India',
#  'Mrs Bectors Food Specialities',
#  'Pokarna',
#  'Century Textiles & Industries',
#  'Kaiser Corporation',
#  'Euphoria Infotech (India)',
#  'Jay Bharat Maruti',
#  'Ashish Polyplast',
#  'Swastik Pipe',
#  'Sasken Technologies',
#  'Panasonic Energy India Company',
#  'Gujarat Containers',
#  'Indokem',
#  'Vasundhara Rasayans',
#  'Netweb Technologies India',
#  'Nifty 200',
#  'Mufin Green Finance',
#  'NILE',
#  'Alfavision Overseas (India)',
#  'Indifra',
#  'Mazagon Dock Shipbuilders',
#  'Endurance Technologies',
#  'JLA Infraville Shoppers',
#  'IND Renewable Energy',
#  'Nifty200 Alpha30',
#  'Hind Aluminium Industries',
#  'Aspinwall & Company',
#  'Speciality Restaurants',
#  'Sai Silks (Kalamandir)',
#  'Daulat Securities',
#  'MRO-TEK Realty',
#  'Engineers India',
#  'Rane Holdings',
#  'NPR Finance',
#  'Capfin India',
#  'Godrej Industries',
#  'The Indian Wood Products Company',
#  'Vikas Wsp',
#  'Toyam Sports',
#  'Omni Axs Software',
#  'Nifty 500',
#  'Sprayking',
#  'Sirca Paints India',
#  'GP Petroleums',
#  'Bright Brothers',
#  'Madras Fertilizers',
#  'Nifty Commodities',
#  'RLF',
#  'Gagan Gases',
#  'HLE Glascoat',
#  'Chamanlal Setia Exports',
#  'Delaplex',
#  'Dwarikesh Sugar Industries',
#  'Marble City India',
#  'Utique Enterprises',
#  'Surat Trade & Merchantile',
#  'Reliance Communications',
#  'Panama Petrochem',
#  'Narmada Agrobase',
#  'Caprolactam Chemicals',
#  'Vedant Asset',
#  'Nifty Tata Group 25% Cap',
#  'Voltaire Leasing & Finance',
#  'Athena Global Technologies',
#  'V B Desai Financial Services',
#  'Centenial Surgical Suture',
#  'Sarvottam Finvest',
#  'Kaarya Facilities & Services',
#  'Arihant Foundations & Housing',
#  'Incap',
#  'Hi-Tech Pipes',
#  'Ajmera Realty & Infra India',
#  'India Nippon Electricals',
#  'IIFL Securities',
#  'Praveg',
#  'Zenith Exports',
#  'Mitcon Consultancy & Engineering Services',
#  'Marvel Decor',
#  'RMC Switchgears',
#  'Polo Queen Industrial and Fintech',
#  'Ramgopal Polytex',
#  'Latteys Industries',
#  'Metropolis Healthcare',
#  'Alpex Solar',
#  'Panjon',
#  'ASM Technologies',
#  'Tata Elxsi',
#  'Santosh Fine Fab',
#  'Rane (Madras)',
#  'Asian Energy Services',
#  'Sagardeep Alloys',
#  'TTK Healthcare',
#  'Welcure Drugs & Pharmaceuticals',
#  'Sizemasters Technology',
#  'Nifty50 TR 1x Inverse',
#  'Innova Captab',
#  'Unique Organics',
#  'VST Industries',
#  'Saroja Pharma Industries India',
#  'Persistent Systems',
#  'Ingersoll-Rand (India)',
#  'Lakshmi Finance & Industrial Corporation',
#  'ADC India Communications',
#  'Praj Industries',
#  'Power & Instrumentation (Gujarat)',
#  'Sacheta Metals',
#  'JSL Industries',
#  'Tasty Bite Eatables',
#  'Libord Finance',
#  'VJTF Eduservices',
#  'Samvardhana Motherson International',
#  'Ganga Papers India',
#  'Kaira Can Company',
#  'Sanofi India',
#  'Baroda Rayon Corporation',
#  'Iris Clothings',
#  'Concord Control Systems',
#  'Honasa Consumer',
#  'Infomedia Press',
#  'Sunraj Diamond Exports',
#  'Graviss Hospitality',
#  'Infollion Research Services',
#  'Pan Electronics (India)',
#  'Ashok Leyland',
#  'Hitech Corporation',
#  'Jagatjit Industries',
#  'Va Tech Wabag',
#  'Pace E-Commerce Ventures',
#  'Aditya Birla Capital',
#  'Fiem Industries',
#  'Southern Petrochemicals Industries Corporation',
#  'Balmer Lawrie Investment',
#  'Reliance Industries',
#  'MFS Intercorp',
#  'Panchmahal Steel',
#  'Borosil',
#  'Venus Pipes & Tubes',
#  'Talbros Automotive Components',
#  'City Union Bank',
#  'IB Infotech Enterprises',
#  'IndusInd Bank',
#  'Palash Securities',
#  'Vishnu Chemicals',
#  'New India Assurance Company',
#  'Indag Rubber',
#  'SVS Ventures',
#  'Victoria Mills',
#  'Cigniti Technologies',
#  'Oriental Hotels',
#  'Organic Recycling Systems',
#  'AVT Natural Products',
#  'Gufic BioSciences',
#  'NIIT Learning Systems',
#  'Graphisads',
#  'Confidence Futuristic Energetech',
#  'Rail Vikas Nigam',
#  'Madhya Bharat Agro Products',
#  'Eveready Industries India',
#  'Croissance',
#  'Elegant Floriculture & Agrotech (India)',
#  'Beeyu Overseas',
#  'Bodal Chemicals',
#  'Filatex India',
#  'Scan Projects',
#  'Karur Vysya Bank',
#  'Wipro',
#  'AKI India',
#  'Blue Chip India',
#  'Crompton Greaves Consumer Electricals',
#  'Reliance Chemotex Industries',
#  'Aptech',
#  'Knowledge Marine & Engineering Works',
#  'Nahar Capital & Financial Services',
#  'Swaraj Suiting',
#  'Anand Rayons',
#  'Benares Hotels',
#  'Tata Communications',
#  'L&T Technology Services',
#  'Aayush Food And Herbs',
#  'K G Denim',
#  'Latent View Analytics',
#  'Pavna Industries',
#  'Cera Sanitaryware',
#  'V B Industries',
#  'Sky Industries',
#  'Satia Industries',
#  'Swiss Military Consumer Goods',
#  '3M India',
#  'Nifty Smallcap 250',
#  'SecureKloud Technologies',
#  'Gokaldas Exports',
#  'Owais Metal and Mineral Processing',
#  'National Aluminium Company',
#  'IVP',
#  'Suraj',
#  'Texmaco Rail & Engineering',
#  'Morganite Crucible (India)',
#  'NCL Research and Financial Services',
#  'Glaxosmithkline Pharmaceuticals',
#  'Divis Laboratories',
#  'Quadrant Televentures',
#  'Kaveri Seed Company',
#  'Vasudhagama Enterprises',
#  'Shree Pacetronix',
#  'Mac Charles (India)',
#  'AYM Syntex',
#  'Biogen Pharmachem Industries',
#  'Angel One',
#  'Systematix Corporate Services',
#  'Standard Capital Markets',
#  'Tata Investment Corporation',
#  'JSW Steel',
#  'Urban Enviro Waste Management',
#  'Deco-Mica',
#  'Chemcon Speciality Chemicals',
#  'Nifty India Consumption',
#  'Yash Management & Satelite',
#  'Rain Industries',
#  'Elantas Beck India',
#  'Zee Learn',
#  'Ajcon Global Services',
#  'Competent Automobiles Company',
#  'Ironwood Education',
#  'Looks Health Services',
#  'Bombay Dyeing & Manufacturing Company',
#  'Winsome Yarns',
#  'Rudrabhishek Enterprises',
#  'Power Grid Corporation of India',
#  'Next Mediaworks',
#  'Vasa Denticity',
#  'Precot',
#  'Aries Agro',
#  'Abans Holdings',
#  'Nectar Lifescience',
#  'Unichem Laboratories',
#  'Oxygenta Pharmaceutical',
#  'Lupin',
#  'Agri-Tech (India)',
#  'Warren Tea',
#  'Orient Bell',
#  'Virgo Global',
#  'Shri Balaji Valve Components',
#  'Star Delta Transformers',
#  'SRG Housing Finance',
#  'Alan Scott Industries',
#  'Colab Cloud Platforms',
#  'Sah Polymers',
#  'Anant Raj',
#  'MAS Financial Services',
#  'Bazel International',
#  'Prismx Global Ventures',
#  'Hi-Green Carbon',
#  'Cyber Media (India)',
#  'Jocil',
#  'Hardcastle & Waud Mfg Co',
#  'Genpharmasec',
#  'Sigachi Industries',
#  'Chambal Fertilisers & Chemicals',
#  'Svaraj Trading & Agencies',
#  'Raconteur Global Resources',
#  'Agro Tech Foods',
#  'Gconnect Logitech & Supply Chain',
#  'NIBE',
#  'Electronics Mart India',
#  'Danlaw Technologies India',
#  'Indian Bright Steel Company',
#  'ROX Hi-Tech',
#  'Vikas Lifecare',
#  'Coromandel International',
#  'Elin Electronics',
#  'Digikore Studios',
#  'Jasch Industries',
#  'Saven Technologies',
#  'New Swan Multitech',
#  'Sat Industries',
#  'Tarapur Transformers',
#  'Oriental Trimex',
#  'ITC',
#  'Kanoria Chemicals & Industries',
#  'NMS Global',
#  'Mahan Industries',
#  'RDB Rasayans',
#  'Elgi Rubber Company',
#  'Bengal Tea & Fabrics',
#  'Tatva Chintan Pharma Chem',
#  'Federal-Mogul Goetze (India)',
#  'Nifty Midcap Select',
#  'Murae Organisor',
#  'Kotak Mahindra Bank',
#  'Titan Company',
#  'Orient Green Power Company',
#  'Agarwal Fortune India',
#  'Available Finance',
#  'Sulabh Engineers & Services',
#  'Vibrant Global Capital',
#  'Avro India',
#  'Krishna Defence & Allied Industries',
#  'Shree OSFM E-Mobility',
#  'Hindustan Composites',
#  'Affordable Robotic & Automation',
#  'Fervent Synergies',
#  'Texmaco Infrastructure & Holdings',
#  'Indiabulls Housing Finance Partly Paidup',
#  'Shree Ganesh Biotech India',
#  'Pearl Polymers',
#  'Scanpoint Geomatics',
#  'Rose Merc.',
#  'SVC Industries',
#  'Uniroyal Industries',
#  'Acme Resources',
#  'HMA Agro Industries',
#  'Himadri Speciality Chemical',
#  'Urja Global',
#  'Amarjothi Spinning Mills',
#  'Samtex Fashions',
#  'MEP Infrastructure Developers',
#  'Anuh Pharma',
#  'N R Agarwal Industries',
#  'Pentokey Organy (India)',
#  'BIGBLOC Construction',
#  'GTPL Hathway',
#  'Roselabs Finance',
#  'Meera Industries',
#  'Hathway Cable & Datacom',
#  'VSF Projects',
#  'Arman Financial Services',
#  'B.C. Power Controls',
#  'Narbada Gems & Jewellery',
#  'Trio Mercantile & Trading',
#  ...]

# %%
len(stock_names)
# Out:
# 4067

# %%
stock_name_fill= stock_names[:50]

# %%
len(stock_name_fill)
# Out:
# 50

# %% [markdown]
# ## symbol work

# %%
import json
from yahooquery import search

found_symbols = {}
not_found_symbols = []

# Iterate over each stock name in the list
for company_name_to_check in stock_name_fill:
    try:
        result = search(company_name_to_check)

        if result['quotes']:
            # Take the first stock symbol from the search results
            stock_symbol = result['quotes'][0]['symbol']
            found_symbols[company_name_to_check] = stock_symbol
            print(f"Stock symbol for {company_name_to_check}: {stock_symbol}")
        else:
            # Handle the case where no stock symbol is found
            not_found_symbols.append(company_name_to_check)
            print(f"No stock symbol found for {company_name_to_check}")
    except Exception as e:
        print(f"Error fetching stock symbol for {company_name_to_check}: {e}")

with open('stock_names.json', 'w') as json_file:
    json.dump(found_symbols, json_file, indent=4)

with open('not_found_stock_symbols.json', 'w') as json_file:
    json.dump(not_found_symbols, json_file, indent=4)

# print("Found stock symbols have been written to found_stock_symbols.json")
# print("Not found stock symbols have been written to not_found_stock_symbols.json")
# Out:
# Stock symbol for SecUR Credentials: SECURCRED.NS
# Stock symbol for United Polyfab Gujarat: UNITEDPOLY.NS
# Stock symbol for Ram Ratna Wires: RAMRAT.NS
# Stock symbol for Jindal Capital: JINDCAP.BO
# Stock symbol for Page Industries: PAGEIND.BO
# Stock symbol for Family Care Hospitals: FAMILYCARE.BO
# Stock symbol for Rathi Bars: RATHIBAR.BO
# Stock symbol for Bella Casa Fashion & Retail: BELLACASA.BO
# Stock symbol for Nalin Lease Finance: NLFL.BO
# Stock symbol for Retina Paints: RETINA.BO
# Stock symbol for Sayaji Hotels (Pune): SHPLPUNE.BO
# Stock symbol for AIA Engineering: AIAENG.BO
# Stock symbol for Haldyn Glass: HALDYNGL.BO
# Stock symbol for Jaiprakash Power Ventures: JPPOWER.NS
# Stock symbol for Laffans Petrochemicals: LAFFANSQ.BO
# No stock symbol found for P B A Infrastructure
# Stock symbol for Shivalik Rasayan: SHIVALIK.NS
# Stock symbol for Career Point: CAREERP.BO
# Stock symbol for Gem Spinners India: GEMSPIN.BO
# Stock symbol for Mangalore Refinery And Petrochemicals: MRPL.NS
# Stock symbol for Tourism Finance Corporation of India: TFCILTD.NS
# Stock symbol for Shiva Mills: SHIVAMILLS.NS
# Stock symbol for Informed Technologies India: INFORTEC.BO
# Stock symbol for Balaxi Pharmaceuticals: BALAXI.NS
# Stock symbol for Kapil Raj Finance: KAPILRAJ.BO
# Stock symbol for Welspun Living: WELSPUNLIV.BO
# Stock symbol for IDBI Bank: IDBI.NS
# Stock symbol for Gayatri Highways: GAYAHWS.NS
# Stock symbol for Pidilite Industries: PIDILITIND.NS
# Stock symbol for Bharat Immunological & Biological Corporation: BIBCL.BO
# Stock symbol for Indo Count Industries: ICIL.NS
# Stock symbol for Ace Integrated Solutions: ACEINTEG.NS
# Stock symbol for Barak Valley Cements: BVCL.BO
# No stock symbol found for Ishan International
# Stock symbol for Bharti Airtel: BHARTIARTL.NS
# Stock symbol for Landmark Property Development Company: LPDC.BO
# Stock symbol for Restile Ceramics: RESTILE.BO
# No stock symbol found for Arrowhead Seperation Engineering
# Stock symbol for Megasoft: MEGASOFT.BO
# Stock symbol for Agio Paper & Industries: AGIOPAPER.BO
# Stock symbol for Prakash Woollen & Synthetic Mills: PWASML.BO
# Stock symbol for Polyplex Corporation: POLYPLEX.BO
# Stock symbol for Mawana Sugars: MAWANASUG.BO
# Stock symbol for Modern Insulators: MODINSU.BO
# Stock symbol for Magnum Ventures: MAGNUM.BO
# Stock symbol for Inspire Films: INSPIRE-SM.NS
# Stock symbol for National Fertilizer: NFL.NS
# Stock symbol for K K Fincorp: KKFIN.BO
# Stock symbol for RBM Infracon: RBMINFRA-ST.NS
# Stock symbol for Sandhar Technologies Limited: SANDHAR.NS

# %%
len(found_symbols)
# Out:
# 47

# %%
len(not_found_symbols)
# Out:
# 3
